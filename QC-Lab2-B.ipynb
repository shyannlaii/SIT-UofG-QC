# %%
# %pip install qiskit==1.2.4
# %pip install qiskit-aer==0.15.1
# %pip install pylatexenc==2.10

from qiskit import QuantumCircuit
from qiskit.converters import circuit_to_gate
from qiskit.visualization import array_to_latex
from qiskit.quantum_info import Operator
from qiskit import transpile
from qiskit.providers.basic_provider import BasicSimulator
from qiskit.providers.fake_provider import GenericBackendV2
from qiskit.visualization import plot_histogram
from qiskit.result import marginal_counts
# Out:
# Collecting qiskit==1.2.4
#   Downloading qiskit-1.2.4-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting rustworkx>=0.15.0 (from qiskit==1.2.4)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (1.16.3)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (2.9.0.post0)
# Collecting stevedore>=3.0.0 (from qiskit==1.2.4)
#   Downloading stevedore-5.7.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (4.15.0)
# Collecting symengine<0.14,>=0.11 (from qiskit==1.2.4)
#   Downloading symengine-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit==1.2.4) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->qiskit==1.2.4) (1.3.0)
# Downloading qiskit-1.2.4-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 42.8 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 80.0 MB/s eta 0:00:00
# Downloading stevedore-5.7.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.0 MB/s eta 0:00:00
# Downloading symengine-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 17.9 MB/s eta 0:00:00
# Installing collected packages: symengine, stevedore, rustworkx, qiskit
# Successfully installed qiskit-1.2.4 rustworkx-0.17.1 stevedore-5.7.0 symengine-0.13.0
# Collecting qiskit-aer==0.15.1
#   Downloading qiskit_aer-0.15.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Requirement already satisfied: qiskit>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer==0.15.1) (1.2.4)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer==0.15.1) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer==0.15.1) (1.16.3)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer==0.15.1) (5.9.5)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer==0.15.1) (0.17.1)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer==0.15.1) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer==0.15.1) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer==0.15.1) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer==0.15.1) (5.7.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer==0.15.1) (4.15.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer==0.15.1) (0.13.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit>=1.1.0->qiskit-aer==0.15.1) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit-aer==0.15.1) (1.3.0)
# Downloading qiskit_aer-0.15.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 83.0 MB/s eta 0:00:00
# Installing collected packages: qiskit-aer
# Successfully installed qiskit-aer-0.15.1
# Collecting pylatexenc==2.10
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=bf356298b4853f1625e2eed07880d33c76cfccfbd098528296e3b97f2139d7b9
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10

# %%
# Teleportation
# Create a circuit with 3 qubits (first parameter) and 3 classical bits (second parameter)
teleport = QuantumCircuit(3,3)

# qubit 0 is the state to be teleported from Alice
# qubits 1 and 2 are the shared entangled state
# Alice has qubit 1 (alice half of the entangled pair), Bob has qubit 2 (bob's half)

# Add gates here to entangle qubits 1 and 2
teleport.h(1)      # put qubit 1 into superposition
teleport.cx(1, 2)  # CNOT: entangle qubit 1 and 2

# Add gates here to entangle qubit 0 with the others
# alice entangles her message qubit 0 with her entagled qubit 1
teleport.cx(0, 1)  # CNOT: qubit 0 controls qubit 1
teleport.h(0)      # Hadamard on qubit 0

# Measure qubits 0 and 1 and put the results on classical bits 0 and 1.
teleport.measure([0,1],[0,1])

# Fix up the final state of qubit 2, depending on the measurement results.
# Here we are using a feature of Qiskit that we haven't seen before.
#  bob's connection
with teleport.if_test((1, 1)):  # if classical bit 1 == 1
    teleport.x(2)               # apply X (bit flip) to qubit 2
with teleport.if_test((0, 1)):  # if classical bit 0 == 1
    teleport.z(2)               # apply Z (phase flip) to qubit 2

# Sometimes it's useful to insert a "barrier" to make the diagram clearer.
# A barrier also has an effect on how the circuit is compiled, but we won't worry about that.
teleport.barrier()

# Measure qubit 2 (first parameter) and put the result on classical bit 2 (second parameter)
teleport.measure([2],[2])

# Check the circuit
teleport.draw("mpl")

# %%
# Use a circuit to put qubit 0 into the state that we want to teleport,
# and compose it into the main circuit.

prep = QuantumCircuit(1)
# Add a gate here to put qubit 0 into some state other than |0>
prep.h(0)   # for example, teleport |+> state

# When we compose circuits, the second parameter is the list of qubits (wires) that are being connected
teleport = teleport.compose(prep, [0], front=True)
teleport.draw("mpl")

# %%
# Now simulate and plot the results.
# In general this won't tell us that we have exactly the right state,
# just that we get the right measurement statistics.
# We are interested in the result on classical bit 2, which is the most significant bit (leftmost).
# The simulator adds some noise, so we get some non-zero probabilities for parts of bit 2 that shouldn't be there.
# To see results without noise, add the parameter noise_info=False to GenericBackendV2
# We need to use GenericBackendV2 instead of BasicSimulator, and set control_flow=True, so that we can use if_test.

backend = GenericBackendV2(num_qubits=3, control_flow=True)
compiled = transpile(teleport, backend)
job_sim = backend.run(compiled, shots=1024)
result_sim = job_sim.result()
counts = result_sim.get_counts(compiled)
mcounts = marginal_counts(counts,indices=[2]) # We only want to see the results for bit 2
plot_histogram(mcounts)

# %%
# Teleportation has an interesting feature which is not usually
# included in the description.

# If the qubit being teleported is entangled with other qubits, then after
# teleportation it is still entangled in the same way.

# Try this out!
# You will need to introduce another qubit and entangle it with qubit 0.
# After teleporting, work out how to use measurements to convince yourself that qubit 2 is entangled with the extra qubit.
# You can do this in a similar way to the exercise in Lab1 about Bell states.

# prove that teleport preserves entanglement
# Create a new 4-qubit circuit
teleport2 = QuantumCircuit(4,4)

# Entangle qubit 3 with qubit 0 (Bell pair between them)
teleport2.h(3)
teleport2.cx(3, 0) # qubit 0 now entagled with qubit 3
teleport2.barrier()

# teleport qubit 0 → qubit 2
teleport2.h(1)  # entangle qubit 1 and 2 (shared bell pair for teleportation)
teleport2.cx(1, 2)
teleport2.barrier()

teleport2.cx(0, 1) # alice operation (entangle qubit 0 with 1)
teleport2.h(0)
teleport2.barrier()

# Measure qubits 0 and 1 (Alice's measurement)
teleport2.measure([0, 1], [0, 1])

# Bob's corrections based on Alice's measurement
with teleport2.if_test((1, 1)):
    teleport2.x(2)
with teleport2.if_test((0, 1)):
    teleport2.z(2)

teleport2.barrier()

# Measure qubit 2 AND qubit 3 together
# If entanglement was preserved, they should always match!
teleport2.measure([2, 3], [2, 3])

teleport2.draw("mpl")

# %%
backend = GenericBackendV2(num_qubits=4, control_flow=True)
compiled = transpile(teleport2, backend)
job_sim = backend.run(compiled, shots=1024)
result_sim = job_sim.result()
counts = result_sim.get_counts(compiled)

# Look at bits 2 and 3 together (the two rightmost bits in the output)
mcounts = marginal_counts(counts, indices=[2, 3])
plot_histogram(mcounts)
